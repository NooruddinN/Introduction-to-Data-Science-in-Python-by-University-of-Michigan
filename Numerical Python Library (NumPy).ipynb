# %%
import numpy as np
import math

# %%
a=np.array([1,2,3])

a
# Out:
# array([1, 2, 3])

# %%
print(a.ndim)
# Out:
# 1

# %%
b=np.array([[1,2,3],[1,2,3]])

# %%
b
# Out:
# array([[1, 2, 3],
#        [1, 2, 3]])

# %%
b.shape
# Out:
# (2, 3)

# %%
b.dtype
# Out:
# dtype('int32')

# %%
f=np.arange(10,50,3)

# %%
f
# Out:
# array([10, 13, 16, 19, 22, 25, 28, 31, 34, 37, 40, 43, 46, 49])

# %%
from PIL import Image

from IPython.display import display 

im=Image.open("Capture.png")

display(im)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=280x281 at 0x227D60A4D90>

# %%
a=np.array([[1,2,3],[1,2,3]])

a
# Out:
# array([[1, 2, 3],
#        [1, 2, 3]])

# %%
a>5
# Out:
# array([[False, False, False],
#        [False, False, False]])

# %%
a<2
# Out:
# array([[ True, False, False],
#        [ True, False, False]])
